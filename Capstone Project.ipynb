# %% [markdown]
# # Capstone Project

# %% [markdown]
# The purpose of this project is to create a heatmap of the Milwaukee Police Department's Use of Force incidents performed during the first three quarters of 2020 (the most recent data of this type available). Data is from the City of Milwaukee's Open Data Portal.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
from folium.plugins import HeatMap

from folium.folium import Map
from IPython.display import HTML

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ## Identify Datasets in the Milwaukee Data Portal

# %% [markdown]
# The Milwaukee Police Department (MPD) splits their information up by quarter, so each subject has a separate 2020Q1, 2020Q2, and 2020Q3 components. To use them, these components will need to be combined to show all data currently provided for 2020 (no Q4 data has been published yet).
#
# Also, each quarter's data is split into several different tables which provide little context on their own. In order to get the location of each use of force, tables must be joined to each other (through an additional table) in order to get key columns to match up. Here are the following tables required for each quarter, listing their useful columns:
#
# **AIM_Use_of_Force**  each record represents a use of force by MPD, though some correspond to the same case.
#   *CAD_Call_Number* : matches the *DocumentPoliceNumber* in **Tracs_ContactSummary_Joined**
#
# **Tracs_ContactSummary_Joined**  details for traffic related police activity
#   *DocumentPoliceNumber* :  matches *CAD_Call_Number* in **AIM_Use_of_Force**
#   *Location_ColKey* : matches *CollKey* in **Tracs_Location**
#
# **Tracs_NTC_Joined**  details for non-traffic related police activity
#   *DocumentPoliceNumber* :  matches *CAD_Call_Number* in **AIM_Use_of_Force**
#   *Location_ColKey* : matches *CollKey* in **Tracs_Location**
#
# **Tracs_Warning_Joined**  details for warning related police activity
#   *DocumentPoliceNumber* :  matches *CAD_Call_Number* in **AIM_Use_of_Force**
#   *Location_ColKey* : matches *CollKey* in **Tracs_Location**
#
# **Tracs_ELCI_Joined**  details for electric citation related police activity
#   *DocumentPoliceNumber* :  matches *CAD_Call_Number* in **AIM_Use_of_Force**
#   *Location_ColKey* : matches *CollKey* in **Tracs_Location**
#
# **Tracs_Location**
#   *CollKey* : matches *Location_CollKey* in **Tracs_ContactSummary_Joined**
#   *Latitude*
#   *Longitude*
#
# In total, fifteen tables need to be combined to unite each use of force record with its latitude and longitude, since each of the three quarters' data is split into three tables, and there are five tables per quarter.

# %% [markdown]
# ## Gather data - Quarter 1 2020

# %%
q1force = pd.read_csv('https://data.milwaukee.gov/dataset/9fa186c6-fb69-4cb7-8865-f8fcba1ae2fd/resource/04e4d764-28aa-4c17-a29a-c05532c3901f/download/copy-of-aim-use-of-force-q1-2020-redacted.csv')
q1force.head()
# Out:
#   UOF Report Number incident date    CAD CLEAN  \
# 0      PF-2020-0010      1/4/2020  200040248.0
# 1      PF-2020-0018     1/13/2020  200132357.0
# 2      PF-2020-0018     1/13/2020  200132357.0
# 3      PF-2020-0018     1/13/2020  200132357.0
# 4      PF-2020-0018     1/13/2020  200132357.0
#
#                   Officer Activity Type of Force IncidentPersonID
# 0     Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 1  Effecting ArrestField Interview  Bodily Force         Person 1
# 2  Effecting ArrestField Interview  Bodily Force         Person 1
# 3  Effecting ArrestField Interview  Bodily Force         Person 1
# 4  Effecting ArrestField Interview  Bodily Force         Person 1

# %%
# Number of records
q1force.shape[0]
# Out:
# 72

# %%
# rename some columns to match the headers of Q2 and Q3 tables
q1force.rename(columns={'UOF Report Number': 'UOF_Report_Number', 'incident date': 'incident_date','CAD CLEAN':'CAD_Call_Number', 'Officer Activity':'Officer_Activity', 'Type of Force':'Type_of_Force' }, inplace=True)
q1force.head()
# Out:
#   UOF_Report_Number incident_date  CAD_Call_Number  \
# 0      PF-2020-0010      1/4/2020      200040248.0
# 1      PF-2020-0018     1/13/2020      200132357.0
# 2      PF-2020-0018     1/13/2020      200132357.0
# 3      PF-2020-0018     1/13/2020      200132357.0
# 4      PF-2020-0018     1/13/2020      200132357.0
#
#                   Officer_Activity Type_of_Force IncidentPersonID
# 0     Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 1  Effecting ArrestField Interview  Bodily Force         Person 1
# 2  Effecting ArrestField Interview  Bodily Force         Person 1
# 3  Effecting ArrestField Interview  Bodily Force         Person 1
# 4  Effecting ArrestField Interview  Bodily Force         Person 1

# %%
q1summary = pd.read_csv('https://data.milwaukee.gov/dataset/9fa186c6-fb69-4cb7-8865-f8fcba1ae2fd/resource/c178f5b5-d4e5-4c23-95b0-d829f8d44ada/download/copy-of-tracs-contact-summary-joined-formatted.csv')
q1summary.head()
# Out:
#                                               PrdKey summaryDateOccurred  \
# 0  Formcontactsum00737100601280202008461462274311114           1/28/2020
# 1  Formcontactsum00737100602060202001343369944311473            2/6/2020
# 2  Formcontactsum00737100602100202001512366734311905           2/10/2020
# 3  Formcontactsum00818800601300202008440868943278730           1/30/2020
# 4   Formcontactsum0083920060206020201104446856377978            2/6/2020
#
#   summaryTimeOccurred summaryReason summaryReasonDetail summaryOtherReason  \
# 0                8:43          TS01                VR01                NaN
# 1               13:06          TS01           OR01,SV01                NaN
# 2               13:42          TS01                SV01                NaN
# 3                8:37          TS01                SV01                NaN
# 4                7:20          FI01                  99                NaN
#
#                summaryOtherReasonDetail summaryOutcome  \
# 0                                   NaN          02,03
# 1                                   NaN              4
# 2                                   NaN              4
# 3                                   NaN              3
# 4  SUSPECT INVOLVED IN A DISORDERLY ACT              4
#
#                                    agencyAgencySpace documentPoliceNumber  \
# 0  DEF DRINVING LISTED AUTO, S/B ON N. 27TH ST @ ...            200280642
# 1  I OBSERVED DEF SPEEDING 51MPH ,30 SPEED ZONE A...            200371284
# 2  DEF. DRIVING LISTED AUTO,STOPPED FOR SPEEDING....            200411328
# 3  LISTED SUBJECT WAS OBSERVED TRAVELING ABOVE TH...            200300628
# 4  SUBJECT WENT INTO HER CHILD SCHOOL LOOKING FOR...            200370549
#
#                                       LocationColKey
# 0  Collection00737100601280202008461534347311115#...
# 1  Collection00737100602060202001253863515311237#...
# 2  Collection00737100602100202001512443096311906#...
# 3  Collection00818800601300202008400444419278489#...
# 4  Collection0083920060206020201108162775477982#U...

# %%
# Number of records
q1summary.shape[0]
# Out:
# 15330

# %%
q1nontraffic = pd.read_csv('https://data.milwaukee.gov/dataset/9fa186c6-fb69-4cb7-8865-f8fcba1ae2fd/resource/c08f0515-ea70-407a-954d-e9fedd0cc119/download/copy-of-tracs-ntc-joined-formatted.csv')
q1nontraffic.head()
# Out:
#                                             PrdKey violationDateOccurred  \
# 0    Formntc.frm0128440060118020200445439818107345             1/18/2020
# 1   Formntc.frm01409400602150202003183176134108345             2/15/2020
# 2   Formntc.frm01530200602110202002381040948106980             2/11/2020
# 3    Formntc.frm0171050060219020200246599818106064             2/17/2020
# 4  Formntc.frm017912006012302020022825427231080127             1/23/2020
#
#   violationTimeOccurred          violationLocalOrdinanceDescription  \
# 0                 16:32   ADULT-RETAIL THEFT- VALUE LESS THAN 99.99
# 1                 14:30                             ADULT-VANDALISM
# 2                 14:00  ADULT- RETAIL THEFT VALUE BTWN $100 & $500
# 3                 14:00                             ADULT-VANDALISM
# 4                  1:50         JUV - CURFEW LOIT OF MINOR UNDER 17
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                      110-35-1                         NaN
# 1                        110-15                         NaN
# 2                      110-35-1                         NaN
# 3                        110-15                         NaN
# 4                        106-23                         NaN
#
#   violationStatuteNumber                                  agencyAgencySpace  \
# 0                    NaN  DEFENDANT TOOK ITEMS THAT WERE INTENDED FOR RE...
# 1                    NaN  SUBJECT INTENTIONALLY SMASHED A SMALL LIVING R...
# 2                    NaN  A KNOWN ACTOR INTENTIONALLY AND WITHOUT CONSEN...
# 3                    NaN  LISTED SUBJECT INTENTIONALLY DAMAGED THE VICTI...
# 4                    NaN  LISTED SUBJECT WAS UNDER 17 AND WALKING THROUG...
#
#                                       LocationColKey  \
# 0  Collection012844006011802020045600798391073117...
# 1  Collection014094006021502020032251687091083129...
# 2  Collection015302006021102020024323690491069152...
# 3  Collection017105006021902020025211375461060493...
# 4  Collection017912006012302020023454367521080199...
#
#                                      DefendantColKey  \
# 0  Collection01284400601180202004460116289107379#...
# 1  Collection01409400602150202003184725565108380#...
# 2  Collection015302006021102020023829145281069114...
# 3  Collection017105006021902020024859659711060242...
# 4  Collection017912006012302020022941885471080161...
#
#   documentPoliceNumber\t\t\t\t\t\t\t
# 0            2-0181246\t\t\t\t\t\t\t
# 1            200461397\t\t\t\t\t\t\t
# 2            200421471\t\t\t\t\t\t\t
# 3            200501415\t\t\t\t\t\t\t
# 4            200230147\t\t\t\t\t\t\t

# %%
# rename column to match other quarters
q1nontraffic.rename(columns={'documentPoliceNumber\t\t\t\t\t\t\t': 'documentPoliceNumber'}, inplace=True)
q1nontraffic.head()
# Out:
#                                             PrdKey violationDateOccurred  \
# 0    Formntc.frm0128440060118020200445439818107345             1/18/2020
# 1   Formntc.frm01409400602150202003183176134108345             2/15/2020
# 2   Formntc.frm01530200602110202002381040948106980             2/11/2020
# 3    Formntc.frm0171050060219020200246599818106064             2/17/2020
# 4  Formntc.frm017912006012302020022825427231080127             1/23/2020
#
#   violationTimeOccurred          violationLocalOrdinanceDescription  \
# 0                 16:32   ADULT-RETAIL THEFT- VALUE LESS THAN 99.99
# 1                 14:30                             ADULT-VANDALISM
# 2                 14:00  ADULT- RETAIL THEFT VALUE BTWN $100 & $500
# 3                 14:00                             ADULT-VANDALISM
# 4                  1:50         JUV - CURFEW LOIT OF MINOR UNDER 17
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                      110-35-1                         NaN
# 1                        110-15                         NaN
# 2                      110-35-1                         NaN
# 3                        110-15                         NaN
# 4                        106-23                         NaN
#
#   violationStatuteNumber                                  agencyAgencySpace  \
# 0                    NaN  DEFENDANT TOOK ITEMS THAT WERE INTENDED FOR RE...
# 1                    NaN  SUBJECT INTENTIONALLY SMASHED A SMALL LIVING R...
# 2                    NaN  A KNOWN ACTOR INTENTIONALLY AND WITHOUT CONSEN...
# 3                    NaN  LISTED SUBJECT INTENTIONALLY DAMAGED THE VICTI...
# 4                    NaN  LISTED SUBJECT WAS UNDER 17 AND WALKING THROUG...
#
#                                       LocationColKey  \
# 0  Collection012844006011802020045600798391073117...
# 1  Collection014094006021502020032251687091083129...
# 2  Collection015302006021102020024323690491069152...
# 3  Collection017105006021902020025211375461060493...
# 4  Collection017912006012302020023454367521080199...
#
#                                      DefendantColKey     documentPoliceNumber
# 0  Collection01284400601180202004460116289107379#...  2-0181246\t\t\t\t\t\t\t
# 1  Collection01409400602150202003184725565108380#...  200461397\t\t\t\t\t\t\t
# 2  Collection015302006021102020023829145281069114...  200421471\t\t\t\t\t\t\t
# 3  Collection017105006021902020024859659711060242...  200501415\t\t\t\t\t\t\t
# 4  Collection017912006012302020022941885471080161...  200230147\t\t\t\t\t\t\t

# %%
# remove excess letters from the documentPoliceNumber column
q1nontraffic['documentPoliceNumber']= q1nontraffic['documentPoliceNumber'].str[:9]
q1nontraffic.head()
# Out:
#                                             PrdKey violationDateOccurred  \
# 0    Formntc.frm0128440060118020200445439818107345             1/18/2020
# 1   Formntc.frm01409400602150202003183176134108345             2/15/2020
# 2   Formntc.frm01530200602110202002381040948106980             2/11/2020
# 3    Formntc.frm0171050060219020200246599818106064             2/17/2020
# 4  Formntc.frm017912006012302020022825427231080127             1/23/2020
#
#   violationTimeOccurred          violationLocalOrdinanceDescription  \
# 0                 16:32   ADULT-RETAIL THEFT- VALUE LESS THAN 99.99
# 1                 14:30                             ADULT-VANDALISM
# 2                 14:00  ADULT- RETAIL THEFT VALUE BTWN $100 & $500
# 3                 14:00                             ADULT-VANDALISM
# 4                  1:50         JUV - CURFEW LOIT OF MINOR UNDER 17
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                      110-35-1                         NaN
# 1                        110-15                         NaN
# 2                      110-35-1                         NaN
# 3                        110-15                         NaN
# 4                        106-23                         NaN
#
#   violationStatuteNumber                                  agencyAgencySpace  \
# 0                    NaN  DEFENDANT TOOK ITEMS THAT WERE INTENDED FOR RE...
# 1                    NaN  SUBJECT INTENTIONALLY SMASHED A SMALL LIVING R...
# 2                    NaN  A KNOWN ACTOR INTENTIONALLY AND WITHOUT CONSEN...
# 3                    NaN  LISTED SUBJECT INTENTIONALLY DAMAGED THE VICTI...
# 4                    NaN  LISTED SUBJECT WAS UNDER 17 AND WALKING THROUG...
#
#                                       LocationColKey  \
# 0  Collection012844006011802020045600798391073117...
# 1  Collection014094006021502020032251687091083129...
# 2  Collection015302006021102020024323690491069152...
# 3  Collection017105006021902020025211375461060493...
# 4  Collection017912006012302020023454367521080199...
#
#                                      DefendantColKey documentPoliceNumber
# 0  Collection01284400601180202004460116289107379#...            2-0181246
# 1  Collection01409400602150202003184725565108380#...            200461397
# 2  Collection015302006021102020023829145281069114...            200421471
# 3  Collection017105006021902020024859659711060242...            200501415
# 4  Collection017912006012302020022941885471080161...            200230147

# %%
# Number of records
q1nontraffic.shape[0]
# Out:
# 2218

# %%
q1warning = pd.read_csv('https://data.milwaukee.gov/dataset/9fa186c6-fb69-4cb7-8865-f8fcba1ae2fd/resource/be57487c-7439-4810-a91f-49075e47f52f/download/copy-of-tracs-warning-joined-formatted.csv')
q1warning.head()
# Out:
#                                               PrdKey documentPoliceNumber  \
# 0  Formwarning.fr01476700602250202002215641585106...            200561443
# 1  Formwarning.fr01476800601130202006094926325106...            200132058
# 2   Formwarning.fr0155100060130020200551169818105544            200302136
# 3  Formwarning.fr01551000602060202009220372758105...            200372597
# 4   Formwarning.fr0155100060211020200924169818105544            200422552
#
#   summaryDateOccurred summaryTimeOccurred  \
# 0           2/25/2020               14:21
# 1           1/13/2020               18:09
# 2           1/30/2020               17:51
# 3            2/6/2020               21:22
# 4           2/11/2020               21:24
#
#                                     IndividualColKey  \
# 0  Collection014767006022502020022222341251069257...
# 1  Collection014768006011302020061037532801060594...
# 2  Collection01551000601300202005514249903105547#...
# 3  Collection015510006020602020092228468751055170...
# 4  Collection01551000602110202009245349903105547#...
#
#                                       LocationColKey  \
# 0  Collection014767006022502020022524703071069281...
# 1  Collection01476800601130202006173970629106057#...
# 2  Collection01551000601300202005554830045105584#...
# 3  Collection015510006020602020092516218441055206...
# 4  Collection0155100060211020200929199091105583#U...
#
#                                    agencyAgencySpace
# 0  SUBJECT WAS OBSERVED DRIVING A UNREGISTERED AU...
# 1                                                NaN
# 2  [REDACTED] OBSRVD ABOVE VEH WITH EXPIRED REG 0...
# 3  [REDACTED] OBSERVED ABOVE VEH WITH EXPIRED REG...
# 4  [REDACTED]OBSERVED ABOVE LISTED VEH WITH SUSP ...

# %%
q1warning.shape[0]
# Out:
# 8379

# %%
q1location = pd.read_csv('https://data.milwaukee.gov/dataset/9fa186c6-fb69-4cb7-8865-f8fcba1ae2fd/resource/4cbfb8ad-f198-4434-a97e-87cc17583a43/download/copy-of-tracs-location-formatted.csv')
q1location.head()
# Out:
#                                              CollKey   latitude  longitude
# 0  Collection0051660060123020200844046856305581#U...  43.052939 -87.893371
# 1  Collection0051660060123020200858589603055352#U...  43.052648 -87.892626
# 2  Collection0051660060221020200325475758805557#U...  43.052940 -87.893257
# 3  Collection007369006021402020042548469051142293...  42.988300 -87.905472
# 4  Collection00737100601050202011145011392311397#...  43.026032 -87.992432

# %%
q1electronic = pd.read_csv('https://data.milwaukee.gov/dataset/9fa186c6-fb69-4cb7-8865-f8fcba1ae2fd/resource/5dbd7316-87f8-4b01-9081-b4aa909fa459/download/copy-of-tracs-elci-joined-formatted.csv')
q1electronic.head()
# Out:
#                                              PrdKey violationDateOccurred  \
# 0   Formelci.frm01074700601020202011530447593485269              1/2/2020
# 1    Formelci.frm0107470060107020200228248446485423              1/7/2020
# 2    Formelci.frm0107470060129020200305444622148545             1/29/2020
# 3  Formelci.frm014202006012102020010705893941055400             1/21/2020
# 4  Formelci.frm014202006012102020023248422121055697             1/21/2020
#
#   violationTimeOccurred      violationLocalOrdinanceDescription  \
# 0                 10:23                                 822 OAS
# 1                 13:45                                 822 OAS
# 2                 13:59                       101 OAI COMBO 1ST
# 3                 12:51                                 822 OAS
# 4                 14:32  484 EX POST LIM 25-29 WRK ZONE $272.80
#
#   violationLocalOrdinanceNumber              violationStatuteDescription  \
# 0                       101-1-2               OPERATING AFTER SUSPENSION
# 1                       101-1-2               OPERATING AFTER SUSPENSION
# 2                       101-1-2      OPERATING WHILE UNDER THE INFLUENCE
# 3                       101-1-2               OPERATING AFTER SUSPENSION
# 4                       101-1-2  EXCEEDING SPEED ZONES, ETC. (25-29 MPH)
#
#   violationStatuteNumber agencyAgencySpace  \
# 0           343.44(1)(a)               NaN
# 1           343.44(1)(a)               NaN
# 2           346.63(1)(a)               NaN
# 3           343.44(1)(a)               NaN
# 4              346.57(5)               NaN
#
#                                       LocationColKey  \
# 0  Collection01074700601020202011540334746485400#...
# 1  Collection01074700601070202002282662459485448#...
# 2  Collection01074700601290202004435214528485111#...
# 3  Collection014202006012102020010707108611055425...
# 4  Collection014202006012102020025537706881055753...
#
#                                      DefendantColKey documentPoliceNumber
# 0  Collection01074700601020202011540437184485446#...            200020852
# 1  Collection01074700601070202002175646607485325#...            200071375
# 2  Collection0107470060129020200307263004548580#U...            200291509
# 3  Collection014202006012102020010322231611055381...            200211218
# 4  Collection014202006012102020023555603941055728...            200211477

# %%
q1electronic.shape[0]
# Out:
# 13924

# %%
# Number of records
q1location.shape[0]
# Out:
# 39759

# %% [markdown]
# ## Gather data - Quarter 2 2020

# %%
q2force = pd.read_csv('https://data.milwaukee.gov/dataset/b0e4a98c-ede6-4136-a78a-9d116ada1eef/resource/5b482cdf-790c-47ce-9f8d-c885d62127ff/download/aim_use_of_force-redacted.csv')
q2force.head()
# Out:
#   UOF_Report_Number incident_date  CAD_Call_Number  \
# 0      PF-2020-0197     4/23/2020      201141894.0
# 1      PF-2020-0197     4/23/2020      201141894.0
# 2      PF-2020-0172     4/15/2020      201061190.0
# 3      PF-2020-0244     5/26/2020      201472687.0
# 4      PF-2020-0244     5/26/2020      201472687.0
#
#                                     Officer_Activity    Type_of_Force  \
# 0  Dispatched AssignmentEffecting ArrestField Int...  ECDBodily Force
# 1               Dispatched AssignmentField Interview     Bodily Force
# 2                                       Traffic Stop              ECD
# 3  Effecting ArrestFoot PursuitInvestigationTraff...     Bodily Force
# 4  Effecting ArrestFoot PursuitInvestigationTraff...     Bodily Force
#
#               Justification_for_UOF IncidentPersonID
# 0                               NaN         Person 1
# 1                               NaN         Person 1
# 2                               NaN         Person 1
# 3  Make lawful arrestPrevent Escape         Person 1
# 4  Make lawful arrestPrevent Escape         Person 1

# %%
q2force.shape[0]
# Out:
# 58

# %%
q2summary = pd.read_csv('https://data.milwaukee.gov/dataset/b0e4a98c-ede6-4136-a78a-9d116ada1eef/resource/da63f81a-a4fd-432c-86bd-417763192620/download/tracs_contactsummary_joined-redacted.csv')
q2summary.head()
# Out:
#                                               PrdKey summaryDateOccurred  \
# 0  Formcontactsum00737100605010202008235011392311237            5/1/2020
# 1  Formcontactsum01022100604110202002043648684250116           4/11/2020
# 2  Formcontactsum01022100604160202001014253336250224           4/16/2020
# 3  Formcontactsum01022100604160202001583371206250432           4/16/2020
# 4  Formcontactsum01022100604200202001271373970250685           4/20/2020
#
#   summaryTimeOccurred summaryReason summaryReasonDetail summaryOtherReason  \
# 0                8:13          TS01                SV01                NaN
# 1               13:45          TS01                SV01                NaN
# 2               12:31          TS01                OR01                NaN
# 3               13:47          TS01                OR01                NaN
# 4               13:16          TS01                SV01                NaN
#
#   summaryOtherReasonDetail summaryOutcome  \
# 0                      NaN              4
# 1                      NaN              4
# 2                      NaN              4
# 3                      NaN              4
# 4                      NaN              4
#
#                                    agencyAgencySpace documentPoliceNumber  \
# 0  OBSERVED DEF DRIVING LISTED AUTO, SPEEDING, 66...            201220571
# 1  OBSERV VEH W/B ON W. BOBOLINK AVE SPEEDING 48 ...            201021145
# 2  OBSERV VEH S/B ON N. 103RD ST DISREG STOP SIGN...            201071112
# 3  OBSERV VEH S/B ON N. 103RD ST DISREG STOP SIGN...            201071288
# 4  OBSERV VEH W/B ON W. BOBOLINK AVE SPEEDING 46 ...            201111184
#
#                                       LocationColKey
# 0  Collection00737100605010202008182520747311888#...
# 1  Collection0102210060411020200157387880925089#U...
# 2  Collection01022100604160202012544386492250206#...
# 3  Collection01022100604160202001573457694250425#...
# 4  Collection01022100604200202001244827513250579#...

# %%
q2summary.shape[0]
# Out:
# 6454

# %%
q2nontraffic = pd.read_csv('https://data.milwaukee.gov/dataset/b0e4a98c-ede6-4136-a78a-9d116ada1eef/resource/e683f478-2ca6-4ad7-87dc-bd903276a5b9/download/tracs_ntc_joined-redacted.csv')
q2nontraffic.head()
# Out:
#                                              PrdKey violationDateOccurred  \
# 0   FormntcV3.frm0284970060403020200631503743570047              4/3/2020
# 1  FormntcV3.frm03127300604040202005572415067113958              4/4/2020
# 2   FormntcV3.frm0291970060405020200245057156063557              4/5/2020
# 3   FormntcV3.frm0263400060405020200849448911892753              4/5/2020
# 4   FormntcV3.frm0288000060406020200347388911893153              4/6/2020
#
#   violationTimeOccurred violationLocalOrdinanceDescription  \
# 0                  5:14                            O900440
# 1                 17:57                            O900543
# 2                  1:34                            O900385
# 3                 18:19                            O900385
# 4                 14:53                            O901058
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                      106-31-1                         NaN
# 1                     105-138-2                         NaN
# 2                      106-38-2                         NaN
# 3                      106-38-2                         NaN
# 4                      110-35-1                         NaN
#
#   violationStatuteNumber                                  agencyAgencySpace  \
# 0                    NaN  [REDACTED]. LISTED SUBJ  OBSERVED LOITERING ON...
# 1                    NaN  DEFENDANT INTENTIONALLY AND WITHOUT CONSENT OB...
# 2                    NaN  LISTED SUBJECT HAD A CLEAR CORNER CUT BAGGIE W...
# 3                    NaN  SUBJECT WAS IN POSSESSION OF A GREEN PLANT MAT...
# 4                    NaN  ABOVE LISTED DEFENDANT INTENTIONALLY AND WITHO...
#
#                                       LocationColKey  \
# 0  Collection0284970060403020200643122074770093#U...
# 1  Collection031273006040402020090300385841139136...
# 2  Collection0291970060405020200248243079263587#U...
# 3  Collection02634000604050202008545484067927100#...
# 4  Collection0288000060406020200438237072793198#U...
#
#                                      DefendantColKey  documentPoliceNumber
# 0  Collection028497006040302020064120909170079#UN...           200940413.0
# 1  Collection03127300604040202005590330045113984#...           200951524.0
# 2  Collection0291970060405020200246537880963585#U...           200960166.0
# 3  Collection0263400060405020200851583004592784#U...           200961696.0
# 4  Collection0288000060406020200430106856393181#U...           200971412.0

# %%
q2nontraffic.shape[0]
# Out:
# 324

# %%
q2warning = pd.read_csv('https://data.milwaukee.gov/dataset/b0e4a98c-ede6-4136-a78a-9d116ada1eef/resource/33a4ec7a-ad7b-4f29-b2b1-4ef260474642/download/tracs_warning_joined-redacted.csv')
q2warning.head()
# Out:
#                                               PrdKey documentPoliceNumber  \
# 0  Formwarning.fr01510300605060202012401537188210398            201271116
# 1  Formwarning.fr01510300605090202004584351196210189            201301652
# 2  Formwarning.fr01510300605090202012310790694210887            201301011
# 3  Formwarning.fr01510300605230202003564745113210324            201441429
# 4  Formwarning.fr01510300605260202003355212587210128            201471708
#
#   summaryDateOccurred summaryTimeOccurred  \
# 0            5/6/2020               12:40
# 1            5/9/2020               16:58
# 2            5/9/2020               12:31
# 3           5/23/2020               15:56
# 4           5/26/2020               15:35
#
#                                     IndividualColKey  \
# 0  Collection01510300605060202012404588593210690#...
# 1  Collection0151030060509020200459046737210409#U...
# 2  Collection01510300605090202012313622268210179#...
# 3  Collection01510300605230202003572033044210642#...
# 4  Collection01510300605260202003361080778210320#...
#
#                                       LocationColKey agencyAgencySpace
# 0  Collection0151030060506020201243211333221095#U...               NaN
# 1  Collection01510300605090202005004740110210329#...               NaN
# 2  Collection0151030060509020201232463213210823#U...               NaN
# 3  Collection01510300605230202003593554456210832#...               NaN
# 4  Collection01510300605260202003371147649210880#...               NaN

# %%
q2warning.shape[0]
# Out:
# 3621

# %%
q2electronic = pd.read_csv('https://data.milwaukee.gov/dataset/b0e4a98c-ede6-4136-a78a-9d116ada1eef/resource/89b1a86c-239f-4860-8211-94f269618f99/download/tracs_elci_joined-redacted.csv')
q2electronic.head()
# Out:
#                                             PrdKey violationDateOccurred  \
# 0  Formelci.frm00533900607220201710170873701321119              5/4/2020
# 1  Formelci.frm01510300604300202012555261036210707             4/30/2020
# 2  Formelci.frm01510300605060202001100844535210410              5/6/2020
# 3  Formelci.frm01510300605060202003252620348210459              5/6/2020
# 4  Formelci.frm01510300605070202004422053100210369              5/7/2020
#
#   violationTimeOccurred      violationLocalOrdinanceDescription  \
# 0                 10:33                                     NaN
# 1                 12:55  483 EX POST LIM 20-24 WRK ZONE $222.40
# 2                 13:10  482 EX POST LIM 16-19 WRK ZONE $172.00
# 3                 15:25  483 EX POST LIM 20-24 WRK ZONE $222.40
# 4                 16:42  482 EX POST LIM 16-19 WRK ZONE $172.00
#
#   violationLocalOrdinanceNumber              violationStatuteDescription  \
# 0                           NaN                                      NaN
# 1                       101-1-2  EXCEEDING SPEED ZONES, ETC. (20-24 MPH)
# 2                       101-1-2  EXCEEDING SPEED ZONES, ETC. (16-19 MPH)
# 3                       101-1-2  EXCEEDING SPEED ZONES, ETC. (20-24 MPH)
# 4                       101-1-2  EXCEEDING SPEED ZONES, ETC. (16-19 MPH)
#
#   violationStatuteNumber agencyAgencySpace  \
# 0                    NaN               NaN
# 1              346.57(5)               NaN
# 2              346.57(5)               NaN
# 3              346.57(5)               NaN
# 4              346.57(5)               NaN
#
#                                       LocationColKey  \
# 0                                                NaN
# 1  Collection01510300604300202012575061091210806#...
# 2  Collection01510300605060202001134711659210412#...
# 3  Collection01510300605060202003274220815210711#...
# 4  Collection01510300605070202004442220280210528#...
#
#                                      DefendantColKey documentPoliceNumber
# 0  Collection00533900608100201701271184976265242#...            172030651
# 1  Collection01510300604300202012561010450210901#...            201211157
# 2  Collection0151030060506020200110326143210658#U...            201271222
# 3  Collection01510300605060202003254465058210653#...            201271576
# 4  Collection01510300605070202004423424653210526#...            201281675

# %%
q2electronic.shape[0]
# Out:
# 7352

# %%
q2location = pd.read_csv('https://data.milwaukee.gov/dataset/b0e4a98c-ede6-4136-a78a-9d116ada1eef/resource/1aa96c56-4f3e-4218-b6f6-8a70a33b7d3b/download/tracs_location.csv')
q2location.head()
# Out:
#                                              CollKey   latitude  longitude
# 0  Collection00737100604250202011235349886311596#...  43.063307 -87.940048
# 1  Collection00737100604250202011270432305311821#...  43.063307 -87.940048
# 2  Collection00737100604250202011282136899311995#...  43.063307 -87.940048
# 3  Collection00737100604250202011292450862311157#...  43.063307 -87.940048
# 4  Collection00737100604260202011223921137311864#...  43.051423 -87.947781

# %%
q2location.shape[0]
# Out:
# 17522

# %% [markdown]
# ## Gather data, Quarter 3 2020

# %%
q3force = pd.read_csv('https://data.milwaukee.gov/dataset/930c7e1a-793f-451c-b1dc-ee55946a0545/resource/c4edfeea-a15f-4312-9f60-2fba8aafaeae/download/aim-use-of-force.csv')
q3force.head()
# Out:
#   UOF_Report_Number incident_date  CAD_Call_Number  \
# 0      PF-2020-0315      7/2/2020      201842801.0
# 1      PF-2020-0315      7/2/2020      201842801.0
# 2      PF-2020-0318      7/5/2020      201872089.0
# 3      PF-2020-0318      7/5/2020      201872089.0
# 4      PF-2020-0320      7/6/2020      201880508.0
#
#                                     Officer_Activity            Type_of_Force  \
# 0                                       Traffic Stop             Bodily Force
# 1                                       Traffic Stop             Bodily Force
# 2  Dispatched AssignmentEffecting ArrestField Int...             Bodily Force
# 3  Dispatched AssignmentEffecting ArrestField Int...  Bodily ForceHandcuffing
# 4  Dispatched AssignmentEffecting ArrestField Int...             Bodily Force
#
#                                Justification_for_UOF IncidentPersonID
# 0   Achieve or maintain control of resistive subject         Person 1
# 1   Achieve or maintain control of resistive subject         Person 1
# 2  Achieve or maintain control of resistive subje...         Person 1
# 3  Achieve or maintain control of resistive subje...         Person 1
# 4  Achieve or maintain control of resistive subje...         Person 1

# %%
q3force.shape[0]
# Out:
# 44

# %%
q3summary = pd.read_csv('https://data.milwaukee.gov/dataset/930c7e1a-793f-451c-b1dc-ee55946a0545/resource/378709c9-dbfa-494a-ba35-b3df0ee54a2f/download/tracs-contactsummary-joined.csv')
q3summary.head()
# Out:
#                                               PrdKey summaryDateOccurred  \
# 0  Formcontactsum00937000607250202010530316696107...           7/25/2020
# 1  Formcontactsum00937000609040202002265741103107...            9/4/2020
# 2  Formcontactsum01022100608190202003081948392120...           8/19/2020
# 3  Formcontactsum01022100608190202003410145403120...           8/19/2020
# 4  Formcontactsum01022100608190202011560582232149...           8/19/2020
#
#   summaryTimeOccurred summaryReason summaryReasonDetail summaryOtherReason  \
# 0               10:42          TS01                SV01                NaN
# 1               14:21          TS01                OR01                NaN
# 2               14:52          TS01                OR01                NaN
# 3               15:29          TS01                OR01                NaN
# 4               10:50          TS01           OR01,SV01                NaN
#
#   summaryOtherReasonDetail summaryOutcome  \
# 0                      NaN              4
# 1                      NaN              3
# 2                      NaN              4
# 3                      NaN              4
# 4                      NaN          04,05
#
#                                    agencyAgencySpace documentPoliceNumber  \
# 0                  MP D5 8-4PM  SEE CASE INFORMATION            202070823
# 1  MP D5 8-4PM  FAILURE TO YEILD RIGHT OF WAY ON ...            202481212
# 2                               SEE CASE INFORMATION            202321300
# 3                               SEE CASE INFORMATION            202321370
# 4                               SEE CASE INFORMATION            202320777
#
#                                       LocationColKey
# 0  Collection009370006072502020104619205061072239...
# 1  Collection009370006090402020022526210061072422...
# 2  Collection01022100608190202003055537904120693#...
# 3  Collection010221006081902020033625392441206318...
# 4  Collection01022100608190202011451631655149987#...

# %%
q3summary.shape[0]
# Out:
# 7594

# %%
q3nontraffic = pd.read_csv('https://data.milwaukee.gov/dataset/930c7e1a-793f-451c-b1dc-ee55946a0545/resource/ba592ff8-8714-40c3-9d18-5bc7ca66b5ae/download/tracs-ntc-joined.csv')
q3nontraffic.head()
# Out:
#                                               PrdKey violationDateOccurred  \
# 0   FormntcV3.frm01842900607040202003273289118163653              7/4/2020
# 1   FormntcV3.frm01760200607040202012122515067104756              7/4/2020
# 2   FormntcV3.frm03127800607050202004424819933100464              7/5/2020
# 3  FormntcV3.frm028795006070602020075115390631500110              7/6/2020
# 4   FormntcV3.frm02879500607060202008290913621500224              7/6/2020
#
#   violationTimeOccurred violationLocalOrdinanceDescription  \
# 0                  1:31                            O900543
# 1                 12:12                            O900282
# 2                  3:31                            O900385
# 3                  7:51                            O900454
# 4                  4:44                            O900454
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                     105-138-2                         NaN
# 1                      118-80-1                         NaN
# 2                      106-38-2                         NaN
# 3                        106-23                         NaN
# 4                        106-23                         NaN
#
#   violationStatuteNumber                                  agencyAgencySpace  \
# 0                    NaN  [REDACTED], LOC-63, SUBJECT FLED FROM UNIFORM ...
# 1                    NaN  I OBSERVED THE LISTED VESSEL TRAVELING AT A SP...
# 2                    NaN  SUBJECT WAS OBSERVED IN POSESSION OF A GREEN L...
# 3                    NaN  [REDACTED] LISTED SUBJECT IS UNDER 17 OUTSIDE ...
# 4                    NaN  [REDACTED] LISTED SUBJECT IS UNDER 17 OUTSIDE ...
#
#                                       LocationColKey  \
# 0  Collection01842900607040202003542225565163680#...
# 1  Collection01760200607040202012183332086104797#...
# 2  Collection03127800607050202004113868833100462#...
# 3  Collection028795006071002020021222242191530370...
# 4  Collection028795006070602020075702601541500153...
#
#                                      DefendantColKey  documentPoliceNumber
# 0  Collection01842900607040202003480243702163656#...           201860181.0
# 1  Collection01760200607040202012153744243104784#...           201861085.0
# 2  Collection031278006070502020060819273581225113...           201870549.0
# 3  Collection028795006071002020021222760971530394...           201880373.0
# 4  Collection028795006070602020075547896851500138...           201880373.0

# %%
q3nontraffic.shape[0]
# Out:
# 315

# %%
q3warning = pd.read_csv('https://data.milwaukee.gov/dataset/930c7e1a-793f-451c-b1dc-ee55946a0545/resource/924f437b-75f7-442c-b17a-ef8b0eba7369/download/tracs-warning-joined.csv')
q3warning.head()
# Out:
#                                               PrdKey  documentPoliceNumber  \
# 0   FormwarningV3.0109380060706020200549514969445346           201881936.0
# 1  FormwarningV3.01093800607070202003484365910445983           201891553.0
# 2  FormwarningV3.01093800607070202004110763480445522           201891624.0
# 3   FormwarningV3.0109380060707020200451449353445649           201891728.0
# 4  FormwarningV3.01093800607070202005020346296445354           201891759.0
#
#   summaryDateOccurred summaryTimeOccurred  \
# 0            7/6/2020               17:49
# 1            7/7/2020               15:48
# 2            7/7/2020               16:11
# 3            7/7/2020               16:51
# 4            7/7/2020               17:02
#
#                                     IndividualColKey  \
# 0  Collection01093800607060202005502022836445405#...
# 1  Collection0109380060707020200349168179244545#U...
# 2  Collection01093800607070202004113947840445583#...
# 3  Collection01093800607070202004521777572445711#...
# 4  Collection01093800607070202005023522990445415#...
#
#                                       LocationColKey agencyAgencySpace
# 0  Collection01093800607060202005531045337445587#...               NaN
# 1  Collection01093800607070202003521285121445228#...               NaN
# 2  Collection01093800607070202004163017209445872#...               NaN
# 3  Collection01093800607070202004562761151445972#...               NaN
# 4  Collection01093800607070202005053087678445601#...               NaN

# %%
q3warning.shape[0]
# Out:
# 3561

# %%
q3electronic = pd.read_csv('https://data.milwaukee.gov/dataset/930c7e1a-793f-451c-b1dc-ee55946a0545/resource/71aa9c2f-8b9c-4699-a92a-cf96b64f78cb/download/tracs-elci-joined.csv')
q3electronic.head()
# Out:
#                                               PrdKey violationDateOccurred  \
# 0  FormelciV3.frm00934500608100202011014577420230...             7/12/2020
# 1  FormelciV3.frm00934500609220202011422535607230...             8/17/2020
# 2  FormelciV3.frm00934500609220202012404448589230989             8/19/2020
# 3  FormelciV3.frm00934500609220202012565423307230...             8/22/2020
# 4  FormelciV3.frm00934500609290202004204318022230...              9/5/2020
#
#   violationTimeOccurred violationLocalOrdinanceDescription  \
# 0                  5:34                                NaN
# 1                  3:19                                NaN
# 2                 22:48                                NaN
# 3                 21:21                                NaN
# 4                 19:17                                NaN
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                           NaN                     T105610
# 1                           NaN                     T106735
# 2                           NaN                     T105633
# 3                           NaN                     T105610
# 4                           NaN                     T105610
#
#   violationStatuteNumber                                agencyAgencySpace  \
# 0           346.63(1)(b)                                              NaN
# 1           346.63(1)(b)                                              NaN
# 2          346.63(2)(A)2  I WAS DISPATCHED TO A VEHICLE CRASH. [REDACTED]
# 3           346.63(1)(b)                                              NaN
# 4           346.63(1)(b)                                              NaN
#
#                                       LocationColKey  \
# 0  Collection00934500608100202011055663092309269#...
# 1  Collection009345006092202020114527744992309721...
# 2  Collection00934500609220202012441885472309190#...
# 3  Collection00934500609220202001013066142309481#...
# 4  Collection02264300609050202008482668528341420#...
#
#                                      DefendantColKey documentPoliceNumber
# 0  Collection009345006081002020110556531072309310...            201940470
# 1  Collection009345006092202020114528819612309762...            202300245
# 2  Collection009345006092202020124418512872309231...            202322404
# 3  Collection009345006092202020010130772912309522...            202352277
# 4  Collection02264300609050202008482725290341461#...            202491864

# %%
q3electronic.shape[0]
# Out:
# 8573

# %%
q3location = pd.read_csv('https://data.milwaukee.gov/dataset/930c7e1a-793f-451c-b1dc-ee55946a0545/resource/4d53b5f0-673a-4339-bb8b-abaae9bdcdac/download/tracs-location.csv')
q3location.head()
# Out:
#                                              CollKey   latitude  longitude
# 0  Collection00737100607030202001310046875311167#...  43.062000 -87.936336
# 1  Collection00737100607030202001372990050311237#...  43.061998 -87.936336
# 2  Collection00737100607030202001390351261311273#...  43.061998 -87.936336
# 3  Collection0073710060703020200140188932311372#U...  43.061998 -87.936336
# 4  Collection00737100607040202001413121099311248#...  43.026032 -87.992470

# %%
q3location.shape[0]
# Out:
# 19944

# %% [markdown]
# ## Combine 3 quarters' data into single tables

# %%
force = q1force.append([q2force, q3force])
force.shape[0]
# Out:
# 174

# %%
summary=q1summary.append([q2summary, q3summary])
summary.shape[0]
# Out:
# 29378

# %%
nontraffic=q1nontraffic.append([q2nontraffic, q3nontraffic])
nontraffic.shape[0]
# Out:
# 2857

# %%
warning=q1warning.append([q2warning, q3warning])
warning.shape[0]
# Out:
# 15561

# %%
electronic=q1electronic.append([q2electronic, q3electronic])
electronic.shape[0]
# Out:
# 29849

# %%
#Combine summary, nontraffic, warning, and electronic into a single table, since their information is complimentary
details=summary.append([nontraffic, warning, electronic])
details.shape[0]
# Out:
# 77645

# %%
location=q1location.append([q2location, q3location])
location.shape[0]
# Out:
# 77225

# %% [markdown]
# ## Format tables to facilitate inner joins with "keys" aka common columns

# %%
location.rename(columns={'CollKey': 'LocationColKey'}, inplace=True)
location.head()
# Out:
#                                       LocationColKey   latitude  longitude
# 0  Collection0051660060123020200844046856305581#U...  43.052939 -87.893371
# 1  Collection0051660060123020200858589603055352#U...  43.052648 -87.892626
# 2  Collection0051660060221020200325475758805557#U...  43.052940 -87.893257
# 3  Collection007369006021402020042548469051142293...  42.988300 -87.905472
# 4  Collection00737100601050202011145011392311397#...  43.026032 -87.992432

# %%
force.rename(columns={'CAD_Call_Number': 'documentPoliceNumber'}, inplace=True)
force.head()
# Out:
#   UOF_Report_Number incident_date  documentPoliceNumber  \
# 0      PF-2020-0010      1/4/2020           200040248.0
# 1      PF-2020-0018     1/13/2020           200132357.0
# 2      PF-2020-0018     1/13/2020           200132357.0
# 3      PF-2020-0018     1/13/2020           200132357.0
# 4      PF-2020-0018     1/13/2020           200132357.0
#
#                   Officer_Activity Type_of_Force IncidentPersonID  \
# 0     Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 1  Effecting ArrestField Interview  Bodily Force         Person 1
# 2  Effecting ArrestField Interview  Bodily Force         Person 1
# 3  Effecting ArrestField Interview  Bodily Force         Person 1
# 4  Effecting ArrestField Interview  Bodily Force         Person 1
#
#   Justification_for_UOF
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# remove decimal from documentPoliceNumber
force['documentPoliceNumber'] = force['documentPoliceNumber'].fillna(0).astype(np.int64)
force.head()
# Out:
#   UOF_Report_Number incident_date  documentPoliceNumber  \
# 0      PF-2020-0010      1/4/2020             200040248
# 1      PF-2020-0018     1/13/2020             200132357
# 2      PF-2020-0018     1/13/2020             200132357
# 3      PF-2020-0018     1/13/2020             200132357
# 4      PF-2020-0018     1/13/2020             200132357
#
#                   Officer_Activity Type_of_Force IncidentPersonID  \
# 0     Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 1  Effecting ArrestField Interview  Bodily Force         Person 1
# 2  Effecting ArrestField Interview  Bodily Force         Person 1
# 3  Effecting ArrestField Interview  Bodily Force         Person 1
# 4  Effecting ArrestField Interview  Bodily Force         Person 1
#
#   Justification_for_UOF
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
summary.dtypes
# Out:
# PrdKey                      object
# summaryDateOccurred         object
# summaryTimeOccurred         object
# summaryReason               object
# summaryReasonDetail         object
# summaryOtherReason          object
# summaryOtherReasonDetail    object
# summaryOutcome              object
# agencyAgencySpace           object
# documentPoliceNumber        object
# LocationColKey              object
# dtype: object

# %%
force['documentPoliceNumber'] = force['documentPoliceNumber'].astype(str)
force.head()
# Out:
#   UOF_Report_Number incident_date documentPoliceNumber  \
# 0      PF-2020-0010      1/4/2020            200040248
# 1      PF-2020-0018     1/13/2020            200132357
# 2      PF-2020-0018     1/13/2020            200132357
# 3      PF-2020-0018     1/13/2020            200132357
# 4      PF-2020-0018     1/13/2020            200132357
#
#                   Officer_Activity Type_of_Force IncidentPersonID  \
# 0     Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 1  Effecting ArrestField Interview  Bodily Force         Person 1
# 2  Effecting ArrestField Interview  Bodily Force         Person 1
# 3  Effecting ArrestField Interview  Bodily Force         Person 1
# 4  Effecting ArrestField Interview  Bodily Force         Person 1
#
#   Justification_for_UOF
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# Drop duplicates so that one record per documentPoliceNumber remains
uniqueforce = force.drop_duplicates(subset='documentPoliceNumber', keep="first")
uniqueforce.head()
# Out:
#   UOF_Report_Number incident_date documentPoliceNumber  \
# 0      PF-2020-0010      1/4/2020            200040248
# 1      PF-2020-0018     1/13/2020            200132357
# 5      PF-2020-0021     1/19/2020            200192340
# 6      PF-2020-0027     1/21/2020            200212621
# 8      PF-2020-0030     1/21/2020            200210761
#
#                                     Officer_Activity Type_of_Force  \
# 0                       Effecting ArrestTraffic Stop  Bodily Force
# 1                    Effecting ArrestField Interview  Bodily Force
# 5  Dispatched AssignmentEffecting ArrestField Int...  Bodily Force
# 6                                       Traffic Stop  Bodily Force
# 8                    Effecting ArrestField Interview  Bodily Force
#
#   IncidentPersonID Justification_for_UOF
# 0         Person 1                   NaN
# 1         Person 1                   NaN
# 5         Person 1                   NaN
# 6         Person 1                   NaN
# 8         Person 1                   NaN

# %%
uniqueforce.shape[0]
# Out:
# 104

# %% [markdown]
# ## Combine the uniqueforce, details, and location tables into single table

# %%
locationdetails = pd.merge(details,location, on="LocationColKey")
locationdetails.head()
# Out:
#                                               PrdKey summaryDateOccurred  \
# 0  Formcontactsum00737100601280202008461462274311114           1/28/2020
# 1  Formcontactsum00737100602060202001343369944311473            2/6/2020
# 2  Formcontactsum00737100602100202001512366734311905           2/10/2020
# 3  Formcontactsum00818800601300202008440868943278730           1/30/2020
# 4   Formcontactsum0083920060206020201104446856377978            2/6/2020
#
#   summaryTimeOccurred summaryReason summaryReasonDetail summaryOtherReason  \
# 0                8:43          TS01                VR01                NaN
# 1               13:06          TS01           OR01,SV01                NaN
# 2               13:42          TS01                SV01                NaN
# 3                8:37          TS01                SV01                NaN
# 4                7:20          FI01                  99                NaN
#
#                summaryOtherReasonDetail summaryOutcome  \
# 0                                   NaN          02,03
# 1                                   NaN              4
# 2                                   NaN              4
# 3                                   NaN              3
# 4  SUSPECT INVOLVED IN A DISORDERLY ACT              4
#
#                                    agencyAgencySpace documentPoliceNumber  \
# 0  DEF DRINVING LISTED AUTO, S/B ON N. 27TH ST @ ...            200280642
# 1  I OBSERVED DEF SPEEDING 51MPH ,30 SPEED ZONE A...            200371284
# 2  DEF. DRIVING LISTED AUTO,STOPPED FOR SPEEDING....            200411328
# 3  LISTED SUBJECT WAS OBSERVED TRAVELING ABOVE TH...            200300628
# 4  SUBJECT WENT INTO HER CHILD SCHOOL LOOKING FOR...            200370549
#
#                                       LocationColKey violationDateOccurred  \
# 0  Collection00737100601280202008461534347311115#...                   NaN
# 1  Collection00737100602060202001253863515311237#...                   NaN
# 2  Collection00737100602100202001512443096311906#...                   NaN
# 3  Collection00818800601300202008400444419278489#...                   NaN
# 4  Collection0083920060206020201108162775477982#U...                   NaN
#
#   violationTimeOccurred violationLocalOrdinanceDescription  \
# 0                   NaN                                NaN
# 1                   NaN                                NaN
# 2                   NaN                                NaN
# 3                   NaN                                NaN
# 4                   NaN                                NaN
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   violationStatuteNumber DefendantColKey IndividualColKey   latitude  \
# 0                    NaN             NaN              NaN  43.045115
# 1                    NaN             NaN              NaN  43.051519
# 2                    NaN             NaN              NaN  43.134045
# 3                    NaN             NaN              NaN  43.090058
# 4                    NaN             NaN              NaN  43.077421
#
#    longitude
# 0 -87.947759
# 1 -87.963678
# 2 -87.995137
# 3 -87.992444
# 4 -87.941078

# %%
locationdetails.shape[0]
# Out:
# 79816

# %%
locationdetails.dtypes
# Out:
# PrdKey                                 object
# summaryDateOccurred                    object
# summaryTimeOccurred                    object
# summaryReason                          object
# summaryReasonDetail                    object
# summaryOtherReason                     object
# summaryOtherReasonDetail               object
# summaryOutcome                         object
# agencyAgencySpace                      object
# documentPoliceNumber                   object
# LocationColKey                         object
# violationDateOccurred                  object
# violationTimeOccurred                  object
# violationLocalOrdinanceDescription     object
# violationLocalOrdinanceNumber          object
# violationStatuteDescription            object
# violationStatuteNumber                 object
# DefendantColKey                        object
# IndividualColKey                       object
# latitude                              float64
# longitude                             float64
# dtype: object

# %%
uniqueforce.dtypes
# Out:
# UOF_Report_Number        object
# incident_date            object
# documentPoliceNumber     object
# Officer_Activity         object
# Type_of_Force            object
# IncidentPersonID         object
# Justification_for_UOF    object
# dtype: object

# %%
uniqueforcedata=pd.merge(uniqueforce, locationdetails, on="documentPoliceNumber", how="inner")
uniqueforcedata.head()
# Out:
#   UOF_Report_Number incident_date documentPoliceNumber  \
# 0      PF-2020-0010      1/4/2020            200040248
# 1      PF-2020-0010      1/4/2020            200040248
# 2      PF-2020-0010      1/4/2020            200040248
# 3      PF-2020-0050      2/1/2020            200321753
# 4      PF-2020-0050      2/1/2020            200321753
#
#                Officer_Activity Type_of_Force IncidentPersonID  \
# 0  Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 1  Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 2  Effecting ArrestTraffic Stop  Bodily Force         Person 1
# 3                  Traffic Stop  Bodily Force         Person 1
# 4                  Traffic Stop  Bodily Force         Person 1
#
#   Justification_for_UOF                                             PrdKey  \
# 0                   NaN   Formcontactsum0246200060104020200544002529889235
# 1                   NaN  FormelciV3.frm02462000601040202005403990710889101
# 2                   NaN   FormelciV3.frm0246200060104020200436113743588947
# 3                   NaN  Formcontactsum02849500602120202010031138509116...
# 4                   NaN    FormntcV3.frm0284950060201020200938186439685772
#
#   summaryDateOccurred summaryTimeOccurred summaryReason summaryReasonDetail  \
# 0            1/4/2020                2:13          TS01                VE01
# 1                 NaN                 NaN           NaN                 NaN
# 2                 NaN                 NaN           NaN                 NaN
# 3            2/1/2020               17:02          TS01                VR01
# 4                 NaN                 NaN           NaN                 NaN
#
#   summaryOtherReason summaryOtherReasonDetail summaryOutcome  \
# 0                NaN                      NaN              5
# 1                NaN                      NaN            NaN
# 2                NaN                      NaN            NaN
# 3                NaN                      NaN              5
# 4                NaN                      NaN            NaN
#
#                                    agencyAgencySpace  \
# 0  ATTEMPTED A TRAFFIC STOP FOR DEFECTIVE REG LIG...
# 1                                                NaN
# 2                                                NaN
# 3  LISTED DEFENDANT WAS OPERATING THE LISTED VEHI...
# 4  LISTED DEFENDANT WAS FOUND TO BE IN POSSESSION...
#
#                                       LocationColKey violationDateOccurred  \
# 0  Collection02462000601040202005404068173889126#...                   NaN
# 1  Collection02462000601040202005404068173889126#...              1/4/2020
# 2  Collection02462000601040202005404068141889128#...              1/4/2020
# 3  Collection028495006021202020100336203291164840...                   NaN
# 4  Collection02849500602010202009444386048857139#...              2/1/2020
#
#   violationTimeOccurred violationLocalOrdinanceDescription  \
# 0                   NaN                                NaN
# 1                  2:13                            O900898
# 2                  2:13                            O900023
# 3                   NaN                                NaN
# 4                 17:02                            O900385
#
#   violationLocalOrdinanceNumber violationStatuteDescription  \
# 0                           NaN                         NaN
# 1                       101-1-2                     T105825
# 2                       CIRCUIT                     T104909
# 3                           NaN                         NaN
# 4                      106-38-2                         NaN
#
#   violationStatuteNumber                                    DefendantColKey  \
# 0                    NaN                                                NaN
# 1              347.13(3)  Collection0246200060104020200529516162988978#U...
# 2              346.04(3)  Collection02462000601040202005404032226889176#...
# 3                    NaN                                                NaN
# 4                    NaN  Collection02849500602010202009385584067857100#...
#
#   IndividualColKey   latitude  longitude
# 0              NaN  43.069724 -87.959958
# 1              NaN  43.069724 -87.959958
# 2              NaN  43.069724 -87.959958
# 3              NaN  43.024169 -87.947999
# 4              NaN  43.024170 -87.948052

# %%
uniqueforcedata.shape[0]
# Out:
# 164

# %%
uniqueforcedata.dropna(subset=['latitude', 'longitude'], inplace=True)
uniqueforcedata.shape[0]
# Out:
# 146

# %% [markdown]
# ## Gather & format data - then make the heatmap

# %%
# Milwaukee latitude and longitude values
latitude = 43.05
longitude = -87.92

# %%
# Create map
UseOfForce_map = folium.Map(
    location=[43.05, -87.92],
    tiles='cartodbpositron',
    zoom_start=11)

# display the map
UseOfForce_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add city boundary

boundary = f"https://lio.milwaukeecountywi.gov/arcgis/rest/services/Administrative/Administrative/MapServer/0/query?where=&text=&objectIds=19&time=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&having=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&historicMoment=&returnDistinctValues=false&resultOffset=&resultRecordCount=&queryByDistance=&returnExtentOnly=false&datumTransformation=&parameterValues=&rangeValues=&quantizationParameters=&featureEncoding=esriDefault&f=geojson"

folium.GeoJson(boundary, name="boundary").add_to(UseOfForce_map)
folium.LayerControl().add_to(UseOfForce_map)

UseOfForce_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Link lat/long values from dataframe to map

locs=uniqueforcedata[['latitude','longitude']]
loc_list = locs.values.tolist()
len(loc_list)
loc_list[7]
# Out:
# [43.02417055, -87.9479985]

# %%
#len(loc_list)

for point in range(0, 146):
    folium.Marker(loc_list[point]).add_to(UseOfForce_map)
    
# display the map
UseOfForce_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a heatmap of use of force frequency
ufheat_map = folium.Map(
    location=[43.05, -87.92],
    tiles='cartodbpositron',
    zoom_start=11)

# Create a column in uniqueforcedata that will count each record
uniqueforcedata['count'] = 1

# Add city boundary
folium.GeoJson(boundary, name="boundary").add_to(ufheat_map)

# Create the heatmap using the leaflet plugin
HeatMap(data=uniqueforcedata[['latitude', 'longitude', 'count']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=10, max_zoom=13, name="Use Of Force").add_to(ufheat_map)

# Add layer controls
folium.LayerControl().add_to(ufheat_map)

ufheat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
